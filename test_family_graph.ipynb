# %%
from family_graph import FamilyGraph

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Initialize graph
graph = FamilyGraph()

# %% [markdown]
# # Billeter N° 1
#
# 1\. Heinrich Billeter der Pfister
# von Mänedorf ward Burger &
# Zftr z. Weggen 1609
# ux. Aa Maria Wirth
# > Hs. Caspar 1613-      No 2
#
# ---
# [Dazu auf S. 224:]
# No 2 Pfr. zu Zumikon 1634 zu Wipkingen 1637
# Alumnatsinspektor eod. Pfr. zu Albisrie-
# den 1638
#
# ---
#
# > Susanna 1615-1644
# m. 1633 Christoph Geiger No 6
# Pfr. zu Schwerzenbach 1636 +1665
# Adrian 1617 -      No 3

# %%
# Add Heinrich Billeter N°1:
id1 = graph.add_person({
    "family_id": "Billeter0001",
    "father_family_id": None,
    "family_name": "Billeter",
    "given_name": "Heinrich",
    "birth_year": 1613,
    "death_year": None
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": None,
    "father_family_id": None,
    "husband_family_id": "Billeter0001",
    "family_name": "Wirth",
    "given_name": "Aa Maria",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id1, id2, "HUSBAND_WIFE")

# Add children
id3 = graph.add_person({
    "family_id": "Billeter0002",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Hs. Caspar",
    "birth_year": 1613,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id1, id3, "FATHER_CHILD")
graph.add_relation(id2, id3, "MOTHER_CHILD")

id4 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Susanna",
    "birth_year": 1615,
    "death_year": 1644
})
print(f"id4: {id4}")
graph.add_relation(id1, id4, "FATHER_CHILD")
graph.add_relation(id2, id4, "MOTHER_CHILD")

# Add husband of daughter
id5 = graph.add_person({
    "family_id": "Geiger0006",
    "father_family_id": None,
    "family_name": "Geiger",
    "given_name": "Christoph",
    "birth_year": None,
    "death_year": None
})
print(f"id5: {id5}")
graph.add_relation(id5, id4, "HUSBAND_WIFE")

# Add children
id6 = graph.add_person({
    "family_id": "Billeter0003",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Adrian",
    "birth_year": 1617,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id1, id6, "FATHER_CHILD")
graph.add_relation(id2, id6, "MOTHER_CHILD")

print()
print(graph.G.nodes(data=True))
print()
print(graph.G.edges(data=True))
# Out:
# id1: 20831b71-72dc-4cb7-801a-63db692d6260
# id2: 4c58764e-e839-41e9-9497-210e4bb59c7f
# id3: 00066d3c-eed5-4dfe-8754-2f957d0928c6
# id4: c8f133ab-f478-4d9c-a493-4568216a2dfb
# id5: 150c32e9-259f-43c0-a385-c6aa516e4bd1
# id3: 00066d3c-eed5-4dfe-8754-2f957d0928c6
#
# [(UUID('20831b71-72dc-4cb7-801a-63db692d6260'), {'family_id': 'Billeter0001', 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Heinrich', 'birth_year': 1613, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), {'family_id': None, 'father_family_id': None, 'husband_family_id': None, 'family_name': 'Wirth', 'given_name': 'Aa Maria', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), {'family_id': 'Billeter0002', 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Hs. Caspar', 'birth_year': 1613, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'family_id': None, 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Susanna', 'birth_year': 1615, 'death_year': 1644, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('150c32e9-259f-43c0-a385-c6aa516e4bd1'), {'family_id': 'Geiger0006', 'father_family_id': None, 'family_name': 'Geiger', 'given_name': 'Christoph', 'birth_year': None, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('6dca2153-96cc-4322-bada-c229927c98c8'), {'family_id': 'Billeter0003', 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Adrian', 'birth_year': 1617, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None})]
#
# [(UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), {'relation_type': 'FATHER_CHILD'}), (UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'relation_type': 'FATHER_CHILD'}), (UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('6dca2153-96cc-4322-bada-c229927c98c8'), {'relation_type': 'FATHER_CHILD'}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), {'relation_type': 'MOTHER_CHILD'}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'relation_type': 'MOTHER_CHILD'}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), UUID('6dca2153-96cc-4322-bada-c229927c98c8'), {'relation_type': 'MOTHER_CHILD'}), (UUID('150c32e9-259f-43c0-a385-c6aa516e4bd1'), UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'relation_type': 'HUSBAND_WIFE'})]

# %%
graph.visualize()

# %% [markdown]
# # Billeter N°2
#
# 2\.1 Hs. Caspar 1613-1654
# > ux. Dorothea Irminger
# Antistitis T. Joh. Jakob No 3
#
# V.D.M. 1633 Präceptor  Provisor am Caro-
# linum 1641
# + Melanchol. et Apoplex.
# > Hs. Jakob 1635 -    No 4
# Elisabetha 1636
#
# ---
# [Dazu auf S. 224:]
# Elisabetha g. 1636 > +1719
# m. 1658 Hs. Jakob Vogel
# Gastwirt z. Hecht
# ---
#
# > Emerentiana 1638-
# m. Felix Brysacher
# Pfr. zu Seebach
# Heinrich 1639 +
# Hs. Caspar 1641 -     No 5
# Heinrich 1642-1720
# Buchbinder. Z. z. Weggen 1668
# Dorothea 1645 vide nebenan
#
# ---
# [Dazu auf S. 224:]
# Dorothea 1645-1721
# m. 1689 Salomon Hofmeister No 45
# V.D.M. Provisor
# ---
# > Anna 1649

# %%
# Add Hs. Caspar Billeter N°2:
id1 = graph.add_person({
    "family_id": "Billeter0002",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Hs. Caspar",
    "birth_year": 1613,
    "death_year": 1654
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": None,
    "father_family_id": None,
    "husband_family_id": "Billeter0002",
    "family_name": "Irminger",
    "given_name": "Dorothea",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id1, id2, "HUSBAND_WIFE")

id3 = graph.add_person({
    "family_id": "Jakob0003",
    "father_family_id": None,
    "family_name": "Jakob",
    "given_name": "T. Joh.",
    "birth_year": None,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id3, id2, "HUSBAND_WIFE")

# Add children
id4 = graph.add_person({
    "family_id": "Billeter0004",
    "father_family_id": "Billeter0002",
    "family_name": "Billeter",
    "given_name": "Hs. Jakob",
    "birth_year": 1635,
    "death_year": None
})
print(f"id4: {id4}")
graph.add_relation(id1, id4, "FATHER_CHILD")
graph.add_relation(id2, id4, "MOTHER_CHILD")
id5 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0002",
    "family_name": "Billeter",
    "given_name": "Elisabetha",
    "birth_year": 1636,
    "death_year": None
})
print(f"id5: {id5}")
graph.add_relation(id1, id5, "FATHER_CHILD")
graph.add_relation(id2, id5, "MOTHER_CHILD")
id6 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0002",
    "family_name": "Billeter",
    "given_name": "Emerentiana",
    "birth_year": 1638,
    "death_year": None
})
print(f"id6: {id6}")
graph.add_relation(id1, id6, "FATHER_CHILD")
graph.add_relation(id2, id6, "MOTHER_CHILD")


print()
print(graph.G.nodes(data=True))
print()
print(graph.G.edges(data=True))
# Out:
# id1: 00066d3c-eed5-4dfe-8754-2f957d0928c6
# id2: 2a63c862-605e-4199-9050-05168b88bf4e
# id3: ecfe1065-833c-4919-bf02-b5344a54437e
# id4: 4572803e-7995-4490-b9ca-12fbd37d4c12
# id5: 34ba1d34-20c1-402d-9398-d269f1f7a594
# id6: 250cb16b-dc99-476c-8993-93f60e3b3244
#
# [(UUID('20831b71-72dc-4cb7-801a-63db692d6260'), {'family_id': 'Billeter0001', 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Heinrich', 'birth_year': 1613, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), {'family_id': None, 'father_family_id': None, 'husband_family_id': None, 'family_name': 'Wirth', 'given_name': 'Aa Maria', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), {'family_id': 'Billeter0002', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'given_name': 'Hs. Caspar', 'birth_year': 1613, 'death_year': 1654, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'family_id': None, 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Susanna', 'birth_year': 1615, 'death_year': 1644, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('150c32e9-259f-43c0-a385-c6aa516e4bd1'), {'family_id': 'Geiger0006', 'father_family_id': None, 'family_name': 'Geiger', 'given_name': 'Christoph', 'birth_year': None, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('6dca2153-96cc-4322-bada-c229927c98c8'), {'family_id': 'Billeter0003', 'father_family_id': None, 'family_name': 'Billeter', 'given_name': 'Adrian', 'birth_year': 1617, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('2a63c862-605e-4199-9050-05168b88bf4e'), {'family_id': None, 'father_family_id': None, 'husband_family_id': None, 'family_name': 'Irminger', 'given_name': 'Dorothea', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('ecfe1065-833c-4919-bf02-b5344a54437e'), {'family_id': 'Jakob0003', 'father_family_id': None, 'family_name': 'Jakob', 'given_name': 'T. Joh.', 'birth_year': None, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('4572803e-7995-4490-b9ca-12fbd37d4c12'), {'family_id': 'Billeter0004', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'given_name': 'Hs. Jakob', 'birth_year': 1635, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('34ba1d34-20c1-402d-9398-d269f1f7a594'), {'family_id': None, 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'given_name': 'Elisabetha', 'birth_year': 1636, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None}), (UUID('250cb16b-dc99-476c-8993-93f60e3b3244'), {'family_id': None, 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'given_name': 'Emerentiana', 'birth_year': 1638, 'death_year': None, 'husband_family_id': None, 'profession': None, 'origin': None})]
#
# [(UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), {'relation_type': 'FATHER_CHILD'}), (UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'relation_type': 'FATHER_CHILD'}), (UUID('20831b71-72dc-4cb7-801a-63db692d6260'), UUID('6dca2153-96cc-4322-bada-c229927c98c8'), {'relation_type': 'FATHER_CHILD'}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), {'relation_type': 'MOTHER_CHILD'}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'relation_type': 'MOTHER_CHILD'}), (UUID('4c58764e-e839-41e9-9497-210e4bb59c7f'), UUID('6dca2153-96cc-4322-bada-c229927c98c8'), {'relation_type': 'MOTHER_CHILD'}), (UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), UUID('2a63c862-605e-4199-9050-05168b88bf4e'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), UUID('4572803e-7995-4490-b9ca-12fbd37d4c12'), {'relation_type': 'FATHER_CHILD'}), (UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), UUID('34ba1d34-20c1-402d-9398-d269f1f7a594'), {'relation_type': 'FATHER_CHILD'}), (UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'), UUID('250cb16b-dc99-476c-8993-93f60e3b3244'), {'relation_type': 'FATHER_CHILD'}), (UUID('150c32e9-259f-43c0-a385-c6aa516e4bd1'), UUID('c8f133ab-f478-4d9c-a493-4568216a2dfb'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('2a63c862-605e-4199-9050-05168b88bf4e'), UUID('4572803e-7995-4490-b9ca-12fbd37d4c12'), {'relation_type': 'MOTHER_CHILD'}), (UUID('2a63c862-605e-4199-9050-05168b88bf4e'), UUID('34ba1d34-20c1-402d-9398-d269f1f7a594'), {'relation_type': 'MOTHER_CHILD'}), (UUID('2a63c862-605e-4199-9050-05168b88bf4e'), UUID('250cb16b-dc99-476c-8993-93f60e3b3244'), {'relation_type': 'MOTHER_CHILD'}), (UUID('ecfe1065-833c-4919-bf02-b5344a54437e'), UUID('2a63c862-605e-4199-9050-05168b88bf4e'), {'relation_type': 'HUSBAND_WIFE'})]

# %%
graph.family_id_index
# Out:
# {'Billeter0001': UUID('20831b71-72dc-4cb7-801a-63db692d6260'),
#  'Billeter0002': UUID('00066d3c-eed5-4dfe-8754-2f957d0928c6'),
#  'Geiger0006': UUID('150c32e9-259f-43c0-a385-c6aa516e4bd1'),
#  'Billeter0003': UUID('6dca2153-96cc-4322-bada-c229927c98c8'),
#  'Jakob0003': UUID('ecfe1065-833c-4919-bf02-b5344a54437e'),
#  'Billeter0004': UUID('4572803e-7995-4490-b9ca-12fbd37d4c12')}

# %%
graph.visualize()

# %% [markdown]
# 6\.2. Christoph  1607    - 1665
# > ux.1. Susanna Billeter 1633   + 1644
# Pfister Hrch's N° 1 T.
# ux.2. Magdalena Bodmer
# T. v. B. 4

# %%
# Add Susanna Billeter and Christoph Geiger, which are already in graph:
# (they receive the same id as before...)

id1 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Susanna",
    "birth_year": None,
    "death_year": None
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": "Geiger0006",
    "father_family_id": "Geiger0002",
    "family_name": "Geiger",
    "given_name": "Christoph",
    "birth_year": 1607,
    "death_year": 1665
})
print(f"id2: {id2}")
graph.add_relation(id2, id1, "HUSBAND_WIFE")
# Out:
# id1: 87797615-94e3-4b11-ab1d-5ea4c1552806
# id2: 73af3037-6091-4b06-a1a7-0def4fc74b9f

# %%
graph.visualize()

# %%
import networkx as nx
g2 = graph.G
for node in g2.nodes():
    for key, val in g2.nodes[node].items():
        g2.nodes[node][key] = str(g2.nodes[node][key])
nx.write_gexf(g2, 'graph.gexf')
