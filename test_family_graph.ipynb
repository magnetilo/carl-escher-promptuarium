# %%
from family_graph import FamilyGraph

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Initialize graph
graph = FamilyGraph()

# %% [markdown]
# # Billeter N° 1
#
# 1\. Heinrich Billeter der Pfister
# von Mänedorf ward Burger &
# Zftr z. Weggen 1609
# ux. Aa Maria Wirth
# > Hs. Caspar 1613-      No 2
#
# ---
# [Dazu auf S. 224:]
# No 2 Pfr. zu Zumikon 1634 zu Wipkingen 1637
# Alumnatsinspektor eod. Pfr. zu Albisrie-
# den 1638
#
# ---
#
# > Susanna 1615-1644
# m. 1633 Christoph Geiger No 6
# Pfr. zu Schwerzenbach 1636 +1665
# Adrian 1617 -      No 3

# %%
# Add Heinrich Billeter N°1:
id1 = graph.add_person({
    "family_id": "Billeter0001",
    "father_family_id": None,
    "family_name": "Billeter",
    "surname": "Heinrich",
    "birth_year": 1613,
    "death_year": None
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": None,
    "father_family_id": None,
    "family_name": "Wirth",
    "surname": "Aa Maria",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id1, id2, "HUSBAND_WIFE")

# Add children
id3 = graph.add_person({
    "family_id": "Billeter0002",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "surname": "Hs. Caspar",
    "birth_year": 1613,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id1, id3, "FATHER_CHILD")
graph.add_relation(id2, id3, "MOTHER_CHILD")

id4 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "surname": "Susanna",
    "birth_year": 1615,
    "death_year": 1644
})
print(f"id4: {id4}")
graph.add_relation(id1, id4, "FATHER_CHILD")
graph.add_relation(id2, id4, "MOTHER_CHILD")

# Add husband of daughter
id5 = graph.add_person({
    "family_id": "Geiger0006",
    "father_family_id": None,
    "family_name": "Geiger",
    "surname": "Christoph",
    "birth_year": None,
    "death_year": None
})
print(f"id5: {id5}")
graph.add_relation(id5, id4, "HUSBAND_WIFE")

# Add children
id6 = graph.add_person({
    "family_id": "Billeter0003",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "surname": "Adrian",
    "birth_year": 1617,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id1, id6, "FATHER_CHILD")
graph.add_relation(id2, id6, "MOTHER_CHILD")

print()
print(graph.G.nodes(data=True))
print()
print(graph.G.edges(data=True))
# Out:
# id1: 23fd4a98-a063-48b3-a2c6-d5eacade5af9
# id2: 0b56afab-50b9-45f6-af67-60b6bb8a555f
# id3: 98a248a1-5191-4003-87a9-da3415e9367d
# id4: 87797615-94e3-4b11-ab1d-5ea4c1552806
# id5: 73af3037-6091-4b06-a1a7-0def4fc74b9f
# id3: 98a248a1-5191-4003-87a9-da3415e9367d
#
# [(UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), {'family_id': 'Billeter0001', 'father_family_id': None, 'family_name': 'Billeter', 'surname': 'Heinrich', 'birth_year': 1613, 'death_year': None}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), {'family_id': None, 'father_family_id': None, 'family_name': 'Wirth', 'surname': 'Aa Maria', 'birth_year': None, 'death_year': None}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'family_id': 'Billeter0002', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Hs. Caspar', 'birth_year': 1613, 'death_year': None}), (UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'family_id': None, 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Susanna', 'birth_year': 1615, 'death_year': 1644}), (UUID('73af3037-6091-4b06-a1a7-0def4fc74b9f'), {'family_id': 'Geiger0006', 'father_family_id': None, 'family_name': 'Geiger', 'surname': 'Christoph', 'birth_year': None, 'death_year': None}), (UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'family_id': 'Billeter0003', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Adrian', 'birth_year': 1617, 'death_year': None})]
#
# [(UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'relation_type': 'FATHER_CHILD'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'FATHER_CHILD'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'relation_type': 'FATHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'relation_type': 'MOTHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'MOTHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'relation_type': 'MOTHER_CHILD'}), (UUID('73af3037-6091-4b06-a1a7-0def4fc74b9f'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'HUSBAND_WIFE'})]

# %%
graph.visualize()

# %% [markdown]
# # Billeter N°2
#
# 2\.1 Hs. Caspar 1613-1654
# > ux. Dorothea Irminger
# Antistitis T. Joh. Jakob No 3
#
# V.D.M. 1633 Präceptor  Provisor am Caro-
# linum 1641
# + Melanchol. et Apoplex.
# > Hs. Jakob 1635 -    No 4
# Elisabetha 1636
#
# ---
# [Dazu auf S. 224:]
# Elisabetha g. 1636 > +1719
# m. 1658 Hs. Jakob Vogel
# Gastwirt z. Hecht
# ---
#
# > Emerentiana 1638-
# m. Felix Brysacher
# Pfr. zu Seebach
# Heinrich 1639 +
# Hs. Caspar 1641 -     No 5
# Heinrich 1642-1720
# Buchbinder. Z. z. Weggen 1668
# Dorothea 1645 vide nebenan
#
# ---
# [Dazu auf S. 224:]
# Dorothea 1645-1721
# m. 1689 Salomon Hofmeister No 45
# V.D.M. Provisor
# ---
# > Anna 1649

# %%
# Add Hs. Caspar Billeter N°2:
id1 = graph.add_person({
    "family_id": "Billeter0002",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "surname": "Hs. Caspar",
    "birth_year": 1613,
    "death_year": 1654
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": None,
    "father_family_id": None,
    "family_name": "Irminger",
    "surname": "Dorothea",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id1, id2, "HUSBAND_WIFE")

id3 = graph.add_person({
    "family_id": "Jakob0003",
    "father_family_id": None,
    "family_name": "Jakob",
    "surname": "T. Joh.",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id3, id2, "HUSBAND_WIFE")

# Add children
id4 = graph.add_person({
    "family_id": "Billeter0004",
    "father_family_id": "Billeter0003",
    "family_name": "Billeter",
    "surname": "Hs. Jakob",
    "birth_year": 1635,
    "death_year": None
})
print(f"id4: {id4}")
graph.add_relation(id1, id4, "FATHER_CHILD")
graph.add_relation(id2, id4, "MOTHER_CHILD")
id5 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0003",
    "family_name": "Billeter",
    "surname": "Elisabetha",
    "birth_year": 1636,
    "death_year": None
})
print(f"id5: {id5}")
graph.add_relation(id1, id5, "FATHER_CHILD")
graph.add_relation(id2, id5, "MOTHER_CHILD")
id6 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0003",
    "family_name": "Billeter",
    "surname": "Emerentiana",
    "birth_year": 1638,
    "death_year": None
})
print(f"id6: {id6}")
graph.add_relation(id1, id6, "FATHER_CHILD")
graph.add_relation(id2, id6, "MOTHER_CHILD")


print()
print(graph.G.nodes(data=True))
print()
print(graph.G.edges(data=True))
# Out:
# id1: 98a248a1-5191-4003-87a9-da3415e9367d
# id2: e26f3a51-422b-4456-bf5a-e799a9b5fabd
# id2: e26f3a51-422b-4456-bf5a-e799a9b5fabd
# id4: 473f1ce3-a3cc-4968-a2d1-19ed3f081048
# id5: 4662b808-0594-4e85-9d7a-fad1cb993ab1
# id6: 3075f7ec-3811-4370-a87a-6852aba0deaa
#
# [(UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), {'family_id': 'Billeter0001', 'father_family_id': None, 'family_name': 'Billeter', 'surname': 'Heinrich', 'birth_year': 1613, 'death_year': None}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), {'family_id': None, 'father_family_id': None, 'family_name': 'Wirth', 'surname': 'Aa Maria', 'birth_year': None, 'death_year': None}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'family_id': 'Billeter0002', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Hs. Caspar', 'birth_year': 1613, 'death_year': None}), (UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'family_id': None, 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Susanna', 'birth_year': 1615, 'death_year': 1644}), (UUID('73af3037-6091-4b06-a1a7-0def4fc74b9f'), {'family_id': 'Geiger0006', 'father_family_id': None, 'family_name': 'Geiger', 'surname': 'Christoph', 'birth_year': None, 'death_year': None}), (UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'family_id': 'Billeter0003', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Adrian', 'birth_year': 1617, 'death_year': None}), (UUID('50a4a66b-2f86-48d9-a862-efdd5fd62458'), {'family_id': None, 'father_family_id': None, 'family_name': 'Irminger', 'surname': 'Dorothea', 'birth_year': None, 'death_year': None}), (UUID('828a582c-7551-43da-9473-02681371efe5'), {'family_id': 'Jakob0003', 'father_family_id': None, 'family_name': 'Jakob', 'surname': 'T. Joh.', 'birth_year': None, 'death_year': None}), (UUID('e26f3a51-422b-4456-bf5a-e799a9b5fabd'), {'family_id': None, 'father_family_id': None, 'family_name': 'Irminger', 'surname': 'Dorothea', 'birth_year': None, 'death_year': None}), (UUID('473f1ce3-a3cc-4968-a2d1-19ed3f081048'), {'family_id': 'Billeter0004', 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'surname': 'Hs. Jakob', 'birth_year': 1635, 'death_year': None}), (UUID('4662b808-0594-4e85-9d7a-fad1cb993ab1'), {'family_id': None, 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'surname': 'Elisabetha', 'birth_year': 1636, 'death_year': None}), (UUID('3075f7ec-3811-4370-a87a-6852aba0deaa'), {'family_id': None, 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'surname': 'Emerentiana', 'birth_year': 1638, 'death_year': None})]
#
# [(UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'relation_type': 'FATHER_CHILD'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'FATHER_CHILD'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'relation_type': 'FATHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'relation_type': 'MOTHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'MOTHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'relation_type': 'MOTHER_CHILD'}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), UUID('50a4a66b-2f86-48d9-a862-efdd5fd62458'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), UUID('e26f3a51-422b-4456-bf5a-e799a9b5fabd'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), UUID('473f1ce3-a3cc-4968-a2d1-19ed3f081048'), {'relation_type': 'FATHER_CHILD'}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), UUID('4662b808-0594-4e85-9d7a-fad1cb993ab1'), {'relation_type': 'FATHER_CHILD'}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), UUID('3075f7ec-3811-4370-a87a-6852aba0deaa'), {'relation_type': 'FATHER_CHILD'}), (UUID('73af3037-6091-4b06-a1a7-0def4fc74b9f'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('828a582c-7551-43da-9473-02681371efe5'), UUID('50a4a66b-2f86-48d9-a862-efdd5fd62458'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('828a582c-7551-43da-9473-02681371efe5'), UUID('e26f3a51-422b-4456-bf5a-e799a9b5fabd'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('e26f3a51-422b-4456-bf5a-e799a9b5fabd'), UUID('473f1ce3-a3cc-4968-a2d1-19ed3f081048'), {'relation_type': 'MOTHER_CHILD'}), (UUID('e26f3a51-422b-4456-bf5a-e799a9b5fabd'), UUID('4662b808-0594-4e85-9d7a-fad1cb993ab1'), {'relation_type': 'MOTHER_CHILD'}), (UUID('e26f3a51-422b-4456-bf5a-e799a9b5fabd'), UUID('3075f7ec-3811-4370-a87a-6852aba0deaa'), {'relation_type': 'MOTHER_CHILD'})]

# %%
graph.visualize()
