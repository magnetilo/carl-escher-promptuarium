# %%
from family_graph import FamilyGraph

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Initialize graph
graph = FamilyGraph()

# %% [markdown]
# # Billeter N° 1
#
# 1\. Heinrich Billeter der Pfister
# von Mänedorf ward Burger &
# Zftr z. Weggen 1609
# ux. Aa Maria Wirth
# > Hs. Caspar 1613-      No 2
#
# ---
# [Dazu auf S. 224:]
# No 2 Pfr. zu Zumikon 1634 zu Wipkingen 1637
# Alumnatsinspektor eod. Pfr. zu Albisrie-
# den 1638
#
# ---
#
# > Susanna 1615-1644
# m. 1633 Christoph Geiger No 6
# Pfr. zu Schwerzenbach 1636 +1665
# Adrian 1617 -      No 3

# %%
# Add Heinrich Billeter N°1:
id1 = graph.add_person({
    "family_id": "Billeter0001",
    "father_family_id": None,
    "family_name": "Billeter",
    "given_name": "Heinrich",
    "birth_year": 1613,
    "death_year": None
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": None,
    "father_family_id": None,
    "family_name": "Wirth",
    "given_name": "Aa Maria",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id1, id2, "HUSBAND_WIFE")

# Add children
id3 = graph.add_person({
    "family_id": "Billeter0002",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Hs. Caspar",
    "birth_year": 1613,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id1, id3, "FATHER_CHILD")
graph.add_relation(id2, id3, "MOTHER_CHILD")

id4 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Susanna",
    "birth_year": 1615,
    "death_year": 1644
})
print(f"id4: {id4}")
graph.add_relation(id1, id4, "FATHER_CHILD")
graph.add_relation(id2, id4, "MOTHER_CHILD")

# Add husband of daughter
id5 = graph.add_person({
    "family_id": "Geiger0006",
    "father_family_id": None,
    "family_name": "Geiger",
    "given_name": "Christoph",
    "birth_year": None,
    "death_year": None
})
print(f"id5: {id5}")
graph.add_relation(id5, id4, "HUSBAND_WIFE")

# Add children
id6 = graph.add_person({
    "family_id": "Billeter0003",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Adrian",
    "birth_year": 1617,
    "death_year": None
})
print(f"id3: {id3}")
graph.add_relation(id1, id6, "FATHER_CHILD")
graph.add_relation(id2, id6, "MOTHER_CHILD")

print()
print(graph.G.nodes(data=True))
print()
print(graph.G.edges(data=True))
# Out:
# id1: 23fd4a98-a063-48b3-a2c6-d5eacade5af9
# id2: 0b56afab-50b9-45f6-af67-60b6bb8a555f
# id3: 98a248a1-5191-4003-87a9-da3415e9367d
# id4: 87797615-94e3-4b11-ab1d-5ea4c1552806
# id5: 73af3037-6091-4b06-a1a7-0def4fc74b9f
# id3: 98a248a1-5191-4003-87a9-da3415e9367d
#
# [(UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), {'family_id': 'Billeter0001', 'father_family_id': None, 'family_name': 'Billeter', 'surname': 'Heinrich', 'birth_year': 1613, 'death_year': None}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), {'family_id': None, 'father_family_id': None, 'family_name': 'Wirth', 'surname': 'Aa Maria', 'birth_year': None, 'death_year': None}), (UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'family_id': 'Billeter0002', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Hs. Caspar', 'birth_year': 1613, 'death_year': None}), (UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'family_id': None, 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Susanna', 'birth_year': 1615, 'death_year': 1644}), (UUID('73af3037-6091-4b06-a1a7-0def4fc74b9f'), {'family_id': 'Geiger0006', 'father_family_id': None, 'family_name': 'Geiger', 'surname': 'Christoph', 'birth_year': None, 'death_year': None}), (UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'family_id': 'Billeter0003', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'surname': 'Adrian', 'birth_year': 1617, 'death_year': None})]
#
# [(UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'relation_type': 'FATHER_CHILD'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'FATHER_CHILD'}), (UUID('23fd4a98-a063-48b3-a2c6-d5eacade5af9'), UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'relation_type': 'FATHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('98a248a1-5191-4003-87a9-da3415e9367d'), {'relation_type': 'MOTHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'MOTHER_CHILD'}), (UUID('0b56afab-50b9-45f6-af67-60b6bb8a555f'), UUID('67eba151-a4bb-497c-b70c-6553db7466d3'), {'relation_type': 'MOTHER_CHILD'}), (UUID('73af3037-6091-4b06-a1a7-0def4fc74b9f'), UUID('87797615-94e3-4b11-ab1d-5ea4c1552806'), {'relation_type': 'HUSBAND_WIFE'})]

# %%
graph.visualize()

# %% [markdown]
# # Billeter N°2
#
# 2\.1 Hs. Caspar 1613-1654
# > ux. Dorothea Irminger
# Antistitis T. Joh. Jakob No 3
#
# V.D.M. 1633 Präceptor  Provisor am Caro-
# linum 1641
# + Melanchol. et Apoplex.
# > Hs. Jakob 1635 -    No 4
# Elisabetha 1636
#
# ---
# [Dazu auf S. 224:]
# Elisabetha g. 1636 > +1719
# m. 1658 Hs. Jakob Vogel
# Gastwirt z. Hecht
# ---
#
# > Emerentiana 1638-
# m. Felix Brysacher
# Pfr. zu Seebach
# Heinrich 1639 +
# Hs. Caspar 1641 -     No 5
# Heinrich 1642-1720
# Buchbinder. Z. z. Weggen 1668
# Dorothea 1645 vide nebenan
#
# ---
# [Dazu auf S. 224:]
# Dorothea 1645-1721
# m. 1689 Salomon Hofmeister No 45
# V.D.M. Provisor
# ---
# > Anna 1649

# %%
# Add Hs. Caspar Billeter N°2:
id1 = graph.add_person({
    "family_id": "Billeter0002",
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Hs. Caspar",
    "birth_year": 1613,
    "death_year": 1654
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": None,
    "father_family_id": None,
    "family_name": "Irminger",
    "given_name": "Dorothea",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id1, id2, "HUSBAND_WIFE")

id3 = graph.add_person({
    "family_id": "Jakob0003",
    "father_family_id": None,
    "family_name": "Jakob",
    "given_name": "T. Joh.",
    "birth_year": None,
    "death_year": None
})
print(f"id2: {id2}")
graph.add_relation(id3, id2, "HUSBAND_WIFE")

# Add children
id4 = graph.add_person({
    "family_id": "Billeter0004",
    "father_family_id": "Billeter0003",
    "family_name": "Billeter",
    "given_name": "Hs. Jakob",
    "birth_year": 1635,
    "death_year": None
})
print(f"id4: {id4}")
graph.add_relation(id1, id4, "FATHER_CHILD")
graph.add_relation(id2, id4, "MOTHER_CHILD")
id5 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0003",
    "family_name": "Billeter",
    "given_name": "Elisabetha",
    "birth_year": 1636,
    "death_year": None
})
print(f"id5: {id5}")
graph.add_relation(id1, id5, "FATHER_CHILD")
graph.add_relation(id2, id5, "MOTHER_CHILD")
id6 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0003",
    "family_name": "Billeter",
    "given_name": "Emerentiana",
    "birth_year": 1638,
    "death_year": None
})
print(f"id6: {id6}")
graph.add_relation(id1, id6, "FATHER_CHILD")
graph.add_relation(id2, id6, "MOTHER_CHILD")


print()
print(graph.G.nodes(data=True))
print()
print(graph.G.edges(data=True))
# Out:
# id1: 98ed0bce-5c02-4648-9813-e9a77cf264ab
# id2: 2c9c450f-4232-4a14-a2e8-11df900af909
# id2: 2c9c450f-4232-4a14-a2e8-11df900af909
# id4: f5a9e664-e6d6-4048-aa73-38bb77a2986d
# id5: b7b7eaaf-4485-4c6e-9e21-32726a98ce2e
# id6: 1b3f8cd2-848b-40d4-b31f-8f4e86ad9311
#
# [(UUID('224b5474-1dd2-4ccc-aeb1-405b9dbc7a63'), {'family_id': 'Billeter0002', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'given_name': 'Hs. Caspar', 'birth_year': 1613, 'death_year': 1654, 'profession': None, 'origin': None}), (UUID('bb4f31e9-b212-470a-aec7-c0f69e655932'), {'family_id': None, 'father_family_id': None, 'family_name': 'Irminger', 'given_name': 'Dorothea', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('7fd2adcb-a660-4f5a-8dd0-ad054544440a'), {'family_id': 'Jakob0003', 'father_family_id': None, 'family_name': 'Jakob', 'given_name': 'T. Joh.', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('362b53b5-2e38-448c-af7c-f125f208f795'), {'family_id': 'Billeter0004', 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'given_name': 'Hs. Jakob', 'birth_year': 1635, 'death_year': None, 'profession': None, 'origin': None}), (UUID('a6c257ce-36c1-4cf8-8e28-e093ec8c6a2e'), {'family_id': None, 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'given_name': 'Elisabetha', 'birth_year': 1636, 'death_year': None, 'profession': None, 'origin': None}), (UUID('f417d72e-e0f2-4743-ab37-a940256d6a63'), {'family_id': None, 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'given_name': 'Emerentiana', 'birth_year': 1638, 'death_year': None, 'profession': None, 'origin': None}), (UUID('98ed0bce-5c02-4648-9813-e9a77cf264ab'), {'family_id': 'Billeter0002', 'father_family_id': 'Billeter0001', 'family_name': 'Billeter', 'given_name': 'Hs. Caspar', 'birth_year': 1613, 'death_year': 1654, 'profession': None, 'origin': None}), (UUID('2c9c450f-4232-4a14-a2e8-11df900af909'), {'family_id': None, 'father_family_id': None, 'family_name': 'Irminger', 'given_name': 'Dorothea', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('9a3d0830-b4e3-4b2d-9e9c-8795de58ce0b'), {'family_id': 'Jakob0003', 'father_family_id': None, 'family_name': 'Jakob', 'given_name': 'T. Joh.', 'birth_year': None, 'death_year': None, 'profession': None, 'origin': None}), (UUID('f5a9e664-e6d6-4048-aa73-38bb77a2986d'), {'family_id': 'Billeter0004', 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'given_name': 'Hs. Jakob', 'birth_year': 1635, 'death_year': None, 'profession': None, 'origin': None}), (UUID('b7b7eaaf-4485-4c6e-9e21-32726a98ce2e'), {'family_id': None, 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'given_name': 'Elisabetha', 'birth_year': 1636, 'death_year': None, 'profession': None, 'origin': None}), (UUID('1b3f8cd2-848b-40d4-b31f-8f4e86ad9311'), {'family_id': None, 'father_family_id': 'Billeter0003', 'family_name': 'Billeter', 'given_name': 'Emerentiana', 'birth_year': 1638, 'death_year': None, 'profession': None, 'origin': None})]
#
# [(UUID('224b5474-1dd2-4ccc-aeb1-405b9dbc7a63'), UUID('bb4f31e9-b212-470a-aec7-c0f69e655932'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('224b5474-1dd2-4ccc-aeb1-405b9dbc7a63'), UUID('362b53b5-2e38-448c-af7c-f125f208f795'), {'relation_type': 'FATHER_CHILD'}), (UUID('224b5474-1dd2-4ccc-aeb1-405b9dbc7a63'), UUID('a6c257ce-36c1-4cf8-8e28-e093ec8c6a2e'), {'relation_type': 'FATHER_CHILD'}), (UUID('224b5474-1dd2-4ccc-aeb1-405b9dbc7a63'), UUID('f417d72e-e0f2-4743-ab37-a940256d6a63'), {'relation_type': 'FATHER_CHILD'}), (UUID('bb4f31e9-b212-470a-aec7-c0f69e655932'), UUID('362b53b5-2e38-448c-af7c-f125f208f795'), {'relation_type': 'MOTHER_CHILD'}), (UUID('bb4f31e9-b212-470a-aec7-c0f69e655932'), UUID('a6c257ce-36c1-4cf8-8e28-e093ec8c6a2e'), {'relation_type': 'MOTHER_CHILD'}), (UUID('bb4f31e9-b212-470a-aec7-c0f69e655932'), UUID('f417d72e-e0f2-4743-ab37-a940256d6a63'), {'relation_type': 'MOTHER_CHILD'}), (UUID('7fd2adcb-a660-4f5a-8dd0-ad054544440a'), UUID('bb4f31e9-b212-470a-aec7-c0f69e655932'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('98ed0bce-5c02-4648-9813-e9a77cf264ab'), UUID('2c9c450f-4232-4a14-a2e8-11df900af909'), {'relation_type': 'HUSBAND_WIFE'}), (UUID('98ed0bce-5c02-4648-9813-e9a77cf264ab'), UUID('f5a9e664-e6d6-4048-aa73-38bb77a2986d'), {'relation_type': 'FATHER_CHILD'}), (UUID('98ed0bce-5c02-4648-9813-e9a77cf264ab'), UUID('b7b7eaaf-4485-4c6e-9e21-32726a98ce2e'), {'relation_type': 'FATHER_CHILD'}), (UUID('98ed0bce-5c02-4648-9813-e9a77cf264ab'), UUID('1b3f8cd2-848b-40d4-b31f-8f4e86ad9311'), {'relation_type': 'FATHER_CHILD'}), (UUID('2c9c450f-4232-4a14-a2e8-11df900af909'), UUID('f5a9e664-e6d6-4048-aa73-38bb77a2986d'), {'relation_type': 'MOTHER_CHILD'}), (UUID('2c9c450f-4232-4a14-a2e8-11df900af909'), UUID('b7b7eaaf-4485-4c6e-9e21-32726a98ce2e'), {'relation_type': 'MOTHER_CHILD'}), (UUID('2c9c450f-4232-4a14-a2e8-11df900af909'), UUID('1b3f8cd2-848b-40d4-b31f-8f4e86ad9311'), {'relation_type': 'MOTHER_CHILD'}), (UUID('9a3d0830-b4e3-4b2d-9e9c-8795de58ce0b'), UUID('2c9c450f-4232-4a14-a2e8-11df900af909'), {'relation_type': 'HUSBAND_WIFE'})]

# %%
graph.visualize()

# %% [markdown]
# 6\.2. Christoph  1607    - 1665
# > ux.1. Susanna Billeter 1633   + 1644
# Pfister Hrch's N° 1 T.
# ux.2. Magdalena Bodmer
# T. v. B. 4

# %%
# Add Susanna Billeter and Christoph Geiger, which are already in graph:
# (they receive the same id as before...)

id1 = graph.add_person({
    "family_id": None,
    "father_family_id": "Billeter0001",
    "family_name": "Billeter",
    "given_name": "Susanna",
    "birth_year": None,
    "death_year": None
})
print(f"id1: {id1}")
id2 = graph.add_person({
    "family_id": "Geiger0006",
    "father_family_id": "Geiger0002",
    "family_name": "Geiger",
    "given_name": "Christoph",
    "birth_year": 1607,
    "death_year": 1665
})
print(f"id2: {id2}")
graph.add_relation(id2, id1, "HUSBAND_WIFE")
# Out:
# id1: 87797615-94e3-4b11-ab1d-5ea4c1552806
# id2: 73af3037-6091-4b06-a1a7-0def4fc74b9f

# %%
graph.visualize()

# %%
import networkx as nx
g2 = graph.G
for node in g2.nodes():
    for key, val in g2.nodes[node].items():
        g2.nodes[node][key] = str(g2.nodes[node][key])
nx.write_gexf(g2, 'graph.gexf')
